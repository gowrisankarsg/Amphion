# %%
from models.tts.maskgct.g2p.g2p_generation import g2p, chn_eng_tam_g2p

# %%
sentence = {
  "ta": [
    "காலை வணக்கம், நீங்கள் எப்படி இருக்கிறீர்கள்?",
    "இன்று வானிலை மிகவும் அழகாக இருக்கிறது.",
    "எனக்கு ஒரு கப் காபி வேண்டும்.",
    "இந்த வார இறுதியில் நாம் எங்கே போகிறோம்?",
    "உங்களை சந்தித்ததில் எனக்கு மிக்க மகிழ்ச்சி.",
    "எனக்கு அந்த report இன்னைக்கு evening வேணும்.",
    "நாளைக்கு meeting என்ன டைம்க்கு ஸ்டார்ட் ஆகும்?",
    "இந்த project ரொம்ப interesting-ஆ இருக்கு.",
    "எனக்கு கொஞ்சம் time குடுங்க, நான் check பண்றேன்.",
    "அங்க போறதுக்கு advance-ஆ ticket book பண்ணிடுங்க.",
    "5 கிலோ அரிசி",
    "999 ரூபாய்",
    "2024 ஆம் ஆண்டு"
  ],

  "en": [
    "Hello, how have you been doing lately?",
    "The weather is absolutely beautiful today.",
    "Could I please get a cup of coffee?",
    "Where are we planning to go this weekend?",
    "It was a pleasure meeting you today.",
    "Please send me the report by this evening.",
    "What time does the meeting start tomorrow?",
    "This new project seems really interesting to me.",
    "Give me some time to check the details.",
    "Make sure to book the tickets in advance."
  ],
  "zh": [
    "早上好，你最近怎么样？",
    "今天的天气真的非常好。",
    "请给我来一杯咖啡。",
    "这个周末我们打算去哪里？",
    "今天很高兴能够认识你。",
    "请在今天 evening 之前把 report 发给我。",
    "明天的 meeting 几点开始？",
    "这个新 project 真的很 interesting。",
    "给我一点 time，我来 check 一下。",
    "记得提前 book 那张 ticket。"
  ]
}

# %%
for lang, texts in sentence.items():
  if lang == "ta":
    lang = "Tamil"
  elif lang == "en":
    lang = "English"
  elif lang == "zh":
    lang = "Chinese"

  print("="*75)
  print(f"DEBUG: {lang} G2P conversion Start:")
  for i, text in enumerate(texts):
    print("               --------------------                ")
    print(f"{i+1}. {text}")
    phonemes, tokens = chn_eng_tam_g2p(text)
    print(f"{phonemes} : {tokens}")
    print("               --------------------                ")
  print("="*75)
# Out:
# ...
# DEBUG: Tamil G2P conversion Start:
#                --------------------
# 1. காலை வணக்கம், நீங்கள் எப்படி இருக்கிறீர்கள்?
# k|aː|l|aɪ|_|ʋ|a|ɳ|a|kː|a|m|,|n̪|iː|ŋ|ɡ|a|ɭ|_|e|pː|a|ɖ|i|_|i|ɾ|u|kː|i|r|iː|ɾ|k|a|ɭ|? : [31, 320, 50, 20, 4, 373, 210, 366, 210, 375, 210, 44, 0, 372, 5, 46, 32, 210, 365, 4, 319, 379, 210, 363, 55, 4, 55, 58, 61, 375, 55, 60, 5, 58, 31, 210, 365, 2]
#                --------------------
#                --------------------
# 2. இன்று வானிலை மிகவும் அழகாக இருக்கிறது.
# i|n|d|r|ʉ|_|ʋ|aː|n|i|l|aɪ|_|m|i|ɡ|a|ʋ|u|m|_|a|ɻ|a|ɡ|aː|k|a|_|i|ɾ|u|kː|i|r|a|d̪|ʉ|. : [55, 45, 30, 60, 370, 4, 373, 320, 45, 55, 50, 20, 4, 44, 55, 32, 210, 373, 61, 44, 4, 210, 367, 210, 32, 320, 31, 210, 4, 55, 58, 61, 375, 55, 60, 210, 374, 370, 1]
#                --------------------
#                --------------------
# 3. எனக்கு ஒரு கப் காபி வேண்டும்.
# ...
